# %%
import pandas as pd
data = pd.read_csv(r"C:\WeatherData.csv")
(data)
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h
# 0        1/1/2012 0:00    -1.8              -3.9         86                4  \
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %% [markdown]
# # .head() -->
# it shows the first N rows in the data ( by default, N=5)
# # .shape -->
# it shows the total no. of columns of the dataframe -- not callable
# # .index -->
# This Attribute provides the index of the dataframe -- not callable
# # .columns -->
# it shows the name of each column -- not callable
# # .dtypes -->
# it shows the data-type of each column -- not callable
# # .unique() -->
# In a column, it shows all the unique values, it can be applied on a single column only, not on the whole dataframe
# # .nunique() -->
# it shows the total no. of unique values in each column, it can be applied on a single column as well as on a whole dataframe
# # .count() -->
# it shows the total no. of non-null values in each column, it can be applied on a single column as well as on a whole dataframe
# # .value_counts() -->
# In a column, it shows all the unique values with their count, it can be applied on a single column only
# # .info() -->
# Basic info about the dataframe

# %%
data.head()
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h
# 0  1/1/2012 0:00    -1.8              -3.9         86                4  \
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
# 3  1/1/2012 3:00    -1.5              -3.2         88                6
# 4  1/1/2012 4:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
data.shape
# Out:
# (8784, 8)

# %%
data.index
# Out:
# RangeIndex(start=0, stop=8784, step=1)

# %%
data.columns
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Date/Time            object
# Temp_C              float64
# Dew Point Temp_C    float64
# Rel Hum_%             int64
# Wind Speed_km/h       int64
# Visibility_km       float64
# Press_kPa           float64
# Weather              object
# dtype: object

# %%
data['Wind Speed_km/h'].unique()
# Out:
# array([ 4,  7,  6,  9, 15, 13, 20, 22, 19, 24, 30, 35, 39, 32, 33, 26, 44,
#        43, 48, 37, 28, 17, 11,  0, 83, 70, 57, 46, 41, 52, 50, 63, 54,  2],
#       dtype=int64)

# %%
data.nunique()
data['Weather'].nunique()
# Out:
# 50

# %%
data.count()
data['Weather'].count()
# Out:
# 8784

# %%
data['Weather'].value_counts()
# Out:
# Weather
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# ...

# %% [markdown]
# # 1- Find the number of times when the Weather is exactly Clear
# # 2- Find the number of times when the 'Weather is exactly Clear'
# # 3- Find the number of times when the "Wind Speed wa exactly 4km/h
# # 4- Find out all the Null Values in the Data
# # 5- Rename the column name "Weather" to "Weather Condition"
# # 6- What is the Standard Deviation of "Pressure" ?
# # 7- What is the Variance of "Relative Humidity" ?
# # 8- Find all instances when 'Snow' was recorded
# # 9- Find all instances when "Wind Speed is above 24" and "Visibilty is 25"
# # 10- What is the Mean value of each column against each "Weather Condition"?
# # 11- What is the Min and Max value of each column against each "Weather Condition"
# # 12- Show all teh Records where Weather Condition is Fog
# # 13- Find all instances when "Weather is clear" or "Visibility is above 40"
# # 14- Find all instances when

# %%
print((data["Wind Speed_km/h"].nunique()))
data['Wind Speed_km/h'].unique()
# Out:
# 34
# array([ 4,  7,  6,  9, 15, 13, 20, 22, 19, 24, 30, 35, 39, 32, 33, 26, 44,
#        43, 48, 37, 28, 17, 11,  0, 83, 70, 57, 46, 41, 52, 50, 63, 54,  2],
#       dtype=int64)

# %%
data.groupby("Weather").get_group("Clear")
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h
# 67      1/3/2012 19:00   -16.9             -24.8         50               24  \
# 114     1/5/2012 18:00    -7.1             -14.4         56               11
# 115     1/5/2012 19:00    -9.2             -15.4         61                7
# 116     1/5/2012 20:00    -9.8             -15.7         62                9
# 117     1/5/2012 21:00    -9.0             -14.8         63               13
# ...                ...     ...               ...        ...              ...
# 8646   12/26/2012 6:00   -13.4             -14.8         89                4
# 8698  12/28/2012 10:00    -6.1              -8.6         82               19
# 8713   12/29/2012 1:00   -11.9             -13.6         87               11
# 8714   12/29/2012 2:00   -11.8             -13.1         90               13
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
#       Visibility_km  Press_kPa Weather
# ...

# %%
# data.groupby("Wind Speed")
data[data['Wind Speed_km/h'] == 4]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h
# 0        1/1/2012 0:00    -1.8              -3.9         86                4  \
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 96       1/5/2012 0:00    -8.8             -11.7         79                4
# 101      1/5/2012 5:00    -7.0              -9.5         82                4
# 146      1/7/2012 2:00    -8.1             -11.1         79                4
# ...                ...     ...               ...        ...              ...
# 8768   12/31/2012 8:00    -8.6             -10.3         87                4
# 8769   12/31/2012 9:00    -8.1              -9.6         89                4
# 8770  12/31/2012 10:00    -7.4              -8.9         89                4
# 8772  12/31/2012 12:00    -5.8              -7.5         88                4
# 8773  12/31/2012 13:00    -4.6              -6.6         86                4
#
#       Visibility_km  Press_kPa       Weather
# ...

# %%
data.isnull().count()
# Out:
# Date/Time           8784
# Temp_C              8784
# Dew Point Temp_C    8784
# Rel Hum_%           8784
# Wind Speed_km/h     8784
# Visibility_km       8784
# Press_kPa           8784
# Weather             8784
# dtype: int64

# %%
data.rename(columns= {"Weather": "Weather Condition"}, inplace=True)
print(data.columns)
data.head()
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather Condition'],
#       dtype='object')
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h
# 0  1/1/2012 0:00    -1.8              -3.9         86                4  \
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
# 3  1/1/2012 3:00    -1.5              -3.2         88                6
# 4  1/1/2012 4:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa     Weather Condition
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
data.Press_kPa.std()
# Out:
# 0.8440047459486483

# %%
data['Rel Hum_%'].var()
# Out:
# 286.24855019850196

# %%
data["Weather Condition"].count()
data[data["Weather Condition"]== "Snow"]
data[data['Weather Condition'].str.contains('Snow')].tail(20)
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h
# 41      1/2/2012 17:00    -2.1              -9.5         57               22  \
# 44      1/2/2012 20:00    -5.6             -13.4         54               24
# 45      1/2/2012 21:00    -5.8             -12.8         58               26
# 47      1/2/2012 23:00    -7.4             -14.1         59               17
# 48       1/3/2012 0:00    -9.0             -16.0         57               28
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
data[(data['Wind Speed_km/h'] > 24) & (data["Visibility_km"] == 25)]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h
# 23      1/1/2012 23:00     5.3               2.0         79               30  \
# 24       1/2/2012 0:00     5.2               1.5         77               35
# 25       1/2/2012 1:00     4.6               0.0         72               39
# 26       1/2/2012 2:00     3.9              -0.9         71               32
# 27       1/2/2012 3:00     3.7              -1.5         69               33
# ...                ...     ...               ...        ...              ...
# 8705  12/28/2012 17:00    -8.6             -12.0         76               26
# 8753  12/30/2012 17:00   -12.1             -15.8         74               28
# 8755  12/30/2012 19:00   -13.4             -16.5         77               26
# 8759  12/30/2012 23:00   -12.1             -15.1         78               28
# 8760   12/31/2012 0:00   -11.1             -14.4         77               26
#
# ...

# %%
numeric_col = data.select_dtypes(include='number')
grouped = numeric_col.groupby(data['Weather Condition']).mean()
# data = data.dropna()
grouped = grouped.reset_index()
print(grouped)
# Out:
#                           Weather Condition     Temp_C  Dew Point Temp_C
# 0                                     Clear   6.825716          0.089367  \
# 1                                    Cloudy   7.970544          2.375810
# 2                                   Drizzle   7.353659          5.504878
# 3                               Drizzle,Fog   8.067500          7.033750
# 4                   Drizzle,Ice Pellets,Fog   0.400000         -0.700000
# 5                              Drizzle,Snow   1.050000          0.150000
# 6                          Drizzle,Snow,Fog   0.693333          0.120000
# 7                                       Fog   4.303333          3.159333
# 8                          Freezing Drizzle  -5.657143         -8.000000
# 9                      Freezing Drizzle,Fog  -2.533333         -4.183333
# 10                    Freezing Drizzle,Haze  -5.433333         -8.000000
# 11                    Freezing Drizzle,Snow  -5.109091         -7.072727
# ...

# %%
data.groupby('Weather Condition').max()
data.groupby('Weather Condition').min()
# Out:
#                                                 Date/Time  Temp_C
# Weather Condition
# Clear                                      1/11/2012 1:00   -23.3  \
# Cloudy                                     1/1/2012 17:00   -21.4
# Drizzle                                   1/23/2012 21:00     1.1
# Drizzle,Fog                               1/23/2012 20:00     0.0
# Drizzle,Ice Pellets,Fog                   12/17/2012 9:00     0.4
# Drizzle,Snow                             12/17/2012 15:00     0.9
# Drizzle,Snow,Fog                         12/18/2012 21:00     0.3
# Fog                                         1/1/2012 0:00   -16.0
# Freezing Drizzle                          1/13/2012 10:00    -9.0
# Freezing Drizzle,Fog                        1/1/2012 2:00    -6.4
# Freezing Drizzle,Haze                      2/1/2012 11:00    -5.8
# Freezing Drizzle,Snow                      1/13/2012 3:00    -8.3
# Freezing Fog                               1/22/2012 6:00   -19.0
# ...

# %%
data[(data['Weather Condition'] == 'Clear') | (data['Visibility_km'] > 40)].tail(10)
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h
# 8703  12/28/2012 15:00    -6.8             -10.3         76               24  \
# 8704  12/28/2012 16:00    -7.7             -11.0         77               30
# 8713   12/29/2012 1:00   -11.9             -13.6         87               11
# 8714   12/29/2012 2:00   -11.8             -13.1         90               13
# 8748  12/30/2012 12:00   -12.2             -15.7         75               26
# 8749  12/30/2012 13:00   -12.4             -16.2         73               37
# 8750  12/30/2012 14:00   -11.8             -16.1         70               37
# 8751  12/30/2012 15:00   -11.3             -15.6         70               32
# 8752  12/30/2012 16:00   -11.4             -15.5         72               26
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
#       Visibility_km  Press_kPa Weather Condition
# 8703           48.3     101.22      Mainly Clear
# ...

# %%
# data[(data[''])
data['Date/Time'] = pd.to_datetime(data['Date/Time'])
mask = (((data['Date/Time'] > '2012-6-1') & (data['Date/Time'] <= '2012-6-2')) & ((data['Weather Condition'] == "Rain") | (data['Wind Speed_km/h'] == 19)))
(data.loc[mask])
# Out:
#                Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%
# 3665 2012-06-01 17:00:00    20.2               4.1         35  \
# 3666 2012-06-01 18:00:00    20.1               4.6         36
# 3667 2012-06-01 19:00:00    20.0               5.3         38
# 3669 2012-06-01 21:00:00    19.6               5.7         40
# 3671 2012-06-01 23:00:00    18.2               8.3         52
# 3672 2012-06-02 00:00:00    17.5               8.2         54
#
#       Wind Speed_km/h  Visibility_km  Press_kPa Weather Condition
# 3665               19           48.3     101.03            Cloudy
# 3666               19           24.1     100.98            Cloudy
# 3667               19           25.0     100.88            Cloudy
# 3669               26           25.0     100.80              Rain
# 3671               19           25.0     100.77              Rain
# 3672               15           19.3     100.78              Rain

# %%
data[(data['Weather Condition'] =='Clear') & (data['Rel Hum_%'] > 50)|(data['Visibility_km']> 40)]
# Out:
#                Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%
# 106  2012-01-05 10:00:00    -6.0             -10.0         73  \
# 107  2012-01-05 11:00:00    -5.6             -10.2         70
# 108  2012-01-05 12:00:00    -4.7              -9.6         69
# 109  2012-01-05 13:00:00    -4.4              -9.7         66
# 110  2012-01-05 14:00:00    -5.1             -10.7         65
# ...                  ...     ...               ...        ...
# 8749 2012-12-30 13:00:00   -12.4             -16.2         73
# 8750 2012-12-30 14:00:00   -11.8             -16.1         70
# 8751 2012-12-30 15:00:00   -11.3             -15.6         70
# 8752 2012-12-30 16:00:00   -11.4             -15.5         72
# 8756 2012-12-30 20:00:00   -13.8             -16.5         80
#
#       Wind Speed_km/h  Visibility_km  Press_kPa Weather Condition
# 106                17           48.3     100.45      Mainly Clear
# 107                22           48.3     100.41      Mainly Clear
# ...
